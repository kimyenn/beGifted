# %% [markdown]
# ### From database of companies, pick 3 different retailers to use for testing purposes

# %%
#load data from mongodb's collection of tweets_by_companies into pandas. Run mongod to start mongodb
import pandas as pd
import pymongo
from pymongo import MongoClient
mc = MongoClient()
db = mc.twitter_db
input_data = db.tweets_by_companies
data = pd.DataFrame(list(input_data.find()))

# %%
data['company'] = data['user'].apply(lambda x: x['screen_name'].encode('ascii'))

# %%
data['company'].value_counts()

# %% [markdown]
# ### filter data to only show company name and tweet. Also drop any duplicate tweets

# %%
important_columns = ['company', 'text']
company_tweets = data.loc[: , important_columns]
company_tweets = company_tweets.drop_duplicates()
company_tweets['company'].value_counts()

# %% [markdown]
# ## Start here -------------------------------------------------------------------------

# %%
import pandas as pd
import cPickle as pickle
company_tweets = pd.read_pickle('../data/company_tweets.pkl')

# %%
#mini_retailers_df = company_tweets[(company_tweets['company'] == 'Disney') | (company_tweets['company'] == 'Sephora') | (company_tweets['company'] == 'HomeDepot')]
mini_retailers_df = company_tweets
mini_retailers_df
# Out:
#            company                                               text
# 0       aeriagames  RT @MMOsdotcom: Latest Dragomon Hunter Update ...
# 1       aeriagames  RT @DragomonHunter: Swear allegiance to the Fr...
# 2       aeriagames  We just went live with our new corporate websi...
# 3       aeriagames  RT @EOS_game: Congratulations @Meruna_ for you...
# 4       aeriagames  Congratulations @Meruna_ for the awesome @EOS_...
# 5       aeriagames  RT @bgfcon: "Leveraging human buying behaviors...
# 6       aeriagames  RT @GIBiz: Aeria Games opens new San Francisco...
# 7       aeriagames  The hunt is on! Dragomon Hunter's Open Beta is...
# 8       aeriagames  The closed beta of Dragomon Hunter is now live...
# 9       aeriagames  RT @GamesMarkt: Verstärkung für das @aeriagame...
# 10      aeriagames  Learn more about Dragomon Hunter and see the g...
# 11      aeriagames  Learn more about our upcoming Anime MMO @Drago...
# 12      aeriagames  Echo of Soul is now available on Steam! Add th...
# 13      aeriagames  RT @AppStore: 2011-2012 Champions League winne...
# 14      aeriagames  RT @didierdrogba: Choose &amp; manage your tea...
# 15      aeriagames  The Echo Of Soul Open Beta has started! Embark...
# 16      aeriagames  RT @EOS_game: Echo of Soul has entered closed ...
# 17      aeriagames  RT @EOS_game: EOS goes into closed beta on May...
# 18      aeriagames  RT @didierdrogba: Excited to announce the rele...
# 19      aeriagames  RT @AppStore: Football management powered by @...
# 20      aeriagames  RT @EOS_game: Discover the PVE in @EOS_game, c...
# 21      aeriagames  RT @EOS_game: What did the press think of Echo...
# 22      aeriagames  RT @moltamedia: Capturing great event with @st...
# 23      aeriagames  RT @EOS_game: Prepare yourselves Soulkeepers! ...
# 24      aeriagames  RT @HipChat: After more than doubling employee...
# 25      aeriagames  RT @EOS_game: Echo of Soul was voted the most ...
# 26      aeriagames  With your support we can show the world that E...
# 27      aeriagames  RT @EOS_game: You're about to learn a lot more...
# 28      aeriagames  RT @EOS_game: The developers share some exclus...
# 29      aeriagames  RT @Charlie_Hebdo_: Meilleurs vœux, au fait. h...
# ...            ...                                                ...
# 217644      BNBuzz  "'I hear it when we're walkin' along, but when...
# 217645      BNBuzz  "'Be careful of haints,' the voice said. 'Bett...
# 217646      BNBuzz  "After that it didn't matter whether they went...
# 217647      BNBuzz  "Jem squeezed me into my costume, stood at the...
# 217648      BNBuzz  "When Halloween came, I assumed that the whole...
# 217649      BNBuzz  "Mrs. Merriweather composed a pageant entitled...
# 217650      BNBuzz  "Mrs. Taylor came home from church to find her...
# 217651      BNBuzz  Getting to hear the first chapter of GO SET A ...
# 217652      BNBuzz  "Jem, how can you hate Hitler so bad an' then ...
# 217653      BNBuzz  "Living in this world we HAVE to talk about it...
# 217654      BNBuzz  A very happy #MockingbirdMonday to all! #GoSet...
# 217655      BNBuzz  "'But it's okay to hate Hitler?' 'It is not,' ...
# 217656      BNBuzz  RT @KevinMHaas: Judge Rosemary Collins says At...
# 217657      BNBuzz  RT @JoseforTexas: Stopping by @BNBuzz El Paso ...
# 217658      BNBuzz  "Listen to the verbs in this thing." @WallyLam...
# 217659      BNBuzz  "People were just peculiar. I withdrew from th...
# 217660      BNBuzz  "I love and admire this new book in a way that...
# 217661      BNBuzz  "It's a much gutsier book than TO KILL A MOCKI...
# 217662      BNBuzz  An amazing TO KILL A MOCKINGBIRD conversation ...
# 217663      BNBuzz  "'You're mighty dressed up Miss Jean Louise' s...
# 217664      BNBuzz  "'There's just one kind of folks. Folks." "If ...
# 217665      BNBuzz  "You know she's not used to girls like you. Sh...
# 217666      BNBuzz  "Why ladies hooked woolen rugs on boiling nigh...
# 217667      BNBuzz  "If you had been on that jury, son, and eleven...
# 217668      BNBuzz  "We don't have anything to fear from Bob Ewell...
# 217669      BNBuzz  "There ain't 1 thing in this world I can do ab...
# 217670      BNBuzz  "And I thought to myself, well, we're making a...
# 217671      BNBuzz  RT @LauraM_Martinez: Enjoying guest reading in...
# 217672      BNBuzz  "We're so rarely called on to be Christians, b...
# 217673      BNBuzz  RT @LizaNahas: @BNBuzz #MockingbirdMonday #TKA...
#
# [207237 rows x 2 columns]

# %% [markdown]
# ### Remove all bit.ly and @ tags from stores' tweets

# %%
import re

def remove_links_and_tags(words):
    if 'http' in words or '@' in words:
        return re.sub('(RT)|(RT @[_A-Za-z0-9]+)|(@[_A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', '', words)
    return words 

def remove_links(words):
    if 'http' in words:
        return re.sub('([^0-9A-Za-z \t])|(\w+:\/\/\S+)', '', words)
    return words

# %%
mini_retailers_df['simple_text'] = mini_retailers_df['text'].apply(lambda x: remove_links_and_tags(x))

# %%
mini_retailers_df[mini_retailers_df['company'] =='lululemon'].simple_text
# Out:
# 185414                              The cuddle game is real
# 185415                        Wild thing I think I love you
# 185416                            Howd they keep you toasty
# 185417                      Which pair is on your wish list
# 185418                 For the win Which jacket did you get
# 185419                                      Way to go Coach
# 185420                                       Oh you know us
# 185421                                The old baitandswitch
# 185422     Wow what a hook up But it must be for all the...
# 185423                      Hard to keep it on the down low
# 185424                      Sounds like you scored big time
# 185425         Which pair is giving you those good feelings
# 185426                             Happy to be on your team
# 185427                                    Thats how we roll
# 185428     Its the fuel for your Christmas happiness fue...
# 185429     Good luck on the race this weekend and enjoy ...
# 185430                          Hard work should be treated
# 185431     Great choices Reflective gear is key for runn...
# 185432     We hear you and will be passing along your fe...
# 185433                            We love you five ever too
# 185434     Send us an email at onlinecom and we can work...
# 185435      Our Michigan region teamed up to surprise an...
# 185436                                 You got this Tiffany
# 185437     Oh no Give us a call at 18772639300 or live c...
# 185438      Were curious whats your favourite piece of gear
# 185439     Your yoga teacher deserves a big hug enjoy tr...
# 185440                                  Thanks for the love
# 185441                        The heart wants what it wants
# 185442                         Sounds like were meant to be
# 185443     The holidays are coming up well pass along th...
#                                 ...
# 188609     How about asking for your stocking hung by th...
# 188610     We consider our comeback pretty strong Well b...
# 188611     Us too Were starting to realize that we have ...
# 188612         Sounds like something to be happy over to us
# 188613              Well meet you at the barre with a smile
# 188614     Thats an epic photo The body bends just like ...
# 188615         What piece of gear made you a guest for life
# 188616     Glad our words hit home Keep making it to you...
# 188617     The booty and stems always need special atten...
# 188618              How do you put positivity into practice
# 188619             Oatmeal fuel for a sweaty morning Get it
# 188620     Family and friends take note This girl knows ...
# 188621                                         Life is good
# 188622     You dont look a day over 25 and are rocking t...
# 188623     Some of our styles are reversible so maybe yo...
# 188624                  Youre welcome Have an amazing event
# 188625                             Feeling ready to fly yet
# 188626     Be curious no longer Our reusable bags are du...
# 188627     Cant beat cheap gas Now that you know what fu...
# 188628      What was the best moment in your practice today
# 188629     Think of it as a strength rather than a weakn...
# 188630        Amazing work Some days no equipment is needed
# 188631     Happiness can always be found by getting upsi...
# 188632     Sweaty smiles are our favourite Thanks to you...
# 188633      You guys are burning it up Hope everyone had...
# 188634     Sometimes you have to treat yourself Once a w...
# 188635     You forgot to finish that sentence  and looks...
# 188636     In the medical field or just cant turn down a...
# 188637                           Now that would be the life
# 188638     Its coming In the meantime did you text a spe...
# Name: simple_text, dtype: object

# %% [markdown]
# ### Stemming each tweet

# %%
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

snowball = SnowballStemmer('english')

# %% [markdown]
# ### Python 2 unicode values, translate() only takes a dictionary

# %%
translation_table = dict.fromkeys(map(ord, ')(][:.",!#&;$?'), None)
mini_retailers_df['stemmed_text'] = mini_retailers_df['simple_text'].apply(lambda sent: ' '.join([snowball.stem(word) for \
                                    word in sent.translate(translation_table).split()]))

# %%
mini_retailers_df[mini_retailers_df['company']=='aeriagames'].values[5]
# Out:
# array(['aeriagames',
#        u'RT @bgfcon: "Leveraging human buying behaviors for F2P games success - A devil\'s handbook" by Sebastian Voigt (@aeriagames) https://t.co/4X\u2026',
#        u'  Leveraging human buying behaviors for F2P games success  A devils handbook by Sebastian Voigt  ',
#        u'leverag human buy behavior for f2p game success a devil handbook by sebastian voigt'], dtype=object)

# %% [markdown]
# ### Import sklearn's TfidfVectorizer and create a vector for each company

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from collections import defaultdict

# %%
company_list = mini_retailers_df['company'].value_counts().index
company_list
# Out:
# Index([u'BedBathBeyond', u'Disney', u'AppStore', u'Sephora', u'OldNavy',
#        u'Staples', u'pizzahut', u'Walgreens', u'eBay', u'lushcosmetics',
#        u'IHOP', u'netflix', u'Target', u'Sears', u'Macys', u'Gap', u'Nike',
#        u'Fandango', u'Forever21', u'nikestore', u'HomeDepot', u'Walmart',
#        u'Lowes', u'BestBuy', u'SUBWAY', u'lululemon', u'BananaRepublic',
#        u'ChickfilA', u'QVC', u'zappos', u'Ticketmaster', u'VictoriasSecret',
#        u'ChipotleTweets', u'jcpenney', u'PetSmart', u'hm', u'IKEAUSA',
#        u'bathbodyworks', u'UrbanOutfitters', u'Kohls', u'Nordstrom',
#        u'CVS_Extra', u'tjmaxx', u'DunkinDonuts', u'BNBuzz', u'ContainerStore',
#        u'Cinemark', u'hotelsdotcom', u'Starbucks', u'Aeropostale',
#        u'Cheesecake', u'ULTA_Beauty', u'REI', u'McDonalds', u'SportsAuthority',
#        u'MichaelsStores', u'ToysRUs', u'amazon', u'Etsy', u'redlobster',
#        u'BabiesRUs', u'aeriagames', u'iTunes', u'WholeFoods', u'GameStop',
#        u'tacobell', u'olivegarden'],
#       dtype='object')

# %%
mini_retailers_df['company'].value_counts()

# %%
#turn each company's tweet history into a document
com_docs = []
for company in company_list:
    a = ' '.join([text for text in mini_retailers_df[mini_retailers_df['company']==company].stemmed_text.values])
    com_docs.append(a)

# %%
' '.join([text for text in mini_retailers_df[mini_retailers_df['company']=='Disney'].stemmed_text.values])

# %%
#TFIDF for each company
company_vects = defaultdict(list)
for company in company_list:
    documents = mini_retailers_df[mini_retailers_df['company'] == company].stemmed_text
    vect_name = 'tfidf_'+company
    print documents.values[0]
    company_vects[vect_name] = tfidf.fit_transform(documents)

# %%
company_vects['tfidf_Disney']

# %% [markdown]
# ### Take a shard of users and their tweets

# %%
import pymongo
from pymongo import MongoClient
mc = MongoClient()
db = mc.twitter_db

input_data = db.tweets_by_users
users = pd.DataFrame(list(input_data.find().limit(50000)))

# %%
users['user_name'] = users['user'].apply(lambda x: x['screen_name'].encode('ascii'))

# %%
users['user_name'].value_counts()
# Out:
# USUAggie1990      3232
# chuck_haze        3229
# emiiistyles       3225
# swnseanews        3224
# chunkypots        3221
# ChristinaAAAHD    3215
# quiwop            3213
# nakiyarussell     3199
# lovecoutureee_    3194
# __Ganjaaa         3175
# _justolentino     3166
# matt_brownlee8    3142
# YZAKALLO          3080
# trippnationn      3017
# Itss_angel_cx     2782
# yungjosey         2388
# JULIANAMEGGERS     197
# RadtkeKristin      100
# royray0              1
# Name: user_name, dtype: int64

# %%
important_columns = ['user_name', 'text']
user_df = users.loc[: , important_columns]

# %%
user_df
# Out:
#            user_name                                               text
# 0         chunkypots  @Cheesecake for dinner 💯 https://t.co/Ce3hzP8F0s
# 1         chunkypots                             @thetenspot awesome!!!
# 2         chunkypots              @stajans_girl @pkumaaar_ LMAO YESSSSS
# 3         chunkypots                         💖 https://t.co/cOLa2JYvUC
# 4         chunkypots  @stajans_girl I bought Pooj chocolate dipped O...
# 5         chunkypots  @stajans_girl YO I need to see you soon! Just ...
# 6         chunkypots  Mulberry Cafe has the cutest tree!! https://t....
# 7         chunkypots  Any bobs burger reference makes the fam strong...
# 8         chunkypots  @stajans_girl I want to knit just so I can say...
# 9         chunkypots  @thetenspot what's the name of the quick dry s...
# 10        chunkypots  One week till 🎄 Two weeks till my birthday 👏...
# 11        chunkypots  @JovanHeer @PRANNAmusic BISH please, don't hat...
# 49995  Itss_angel_cx    RT @fuckinfrankkie: you just dont understand 😉
# 49996  Itss_angel_cx           RT @fuckinfrankkie: My stomach hurtss 😭
# 49997  Itss_angel_cx  RT @fuckinfrankkie: dont even kick it with tha...
# 49998  Itss_angel_cx             RT @MickeyLacoste: I need you the most
# 49999  Itss_angel_cx        RT @fuckinfrankkie: @Itss_angel_cx pc | mee
#
# [50000 rows x 2 columns]

# %%
# should rename to stripped_text

user_df['simple_text'] = user_df['text'].apply(lambda x: remove_links(x))

# %%
user_df
# Out:
#            user_name                                               text  \
# 0         chunkypots  @Cheesecake for dinner 💯 https://t.co/Ce3hzP8F0s
# 1         chunkypots                             @thetenspot awesome!!!
# 2         chunkypots              @stajans_girl @pkumaaar_ LMAO YESSSSS
# 3         chunkypots                         💖 https://t.co/cOLa2JYvUC
# 4         chunkypots  @stajans_girl I bought Pooj chocolate dipped O...
# 5         chunkypots  @stajans_girl YO I need to see you soon! Just ...
# 6         chunkypots  Mulberry Cafe has the cutest tree!! https://t....
# 7         chunkypots  Any bobs burger reference makes the fam strong...
# 8         chunkypots  @stajans_girl I want to knit just so I can say...
# 9         chunkypots  @thetenspot what's the name of the quick dry s...
# 10        chunkypots  One week till 🎄 Two weeks till my birthday 👏...
# 11        chunkypots  @JovanHeer @PRANNAmusic BISH please, don't hat...
# 12        chunkypots  🙅🏽 don't mess with chand 💅🏽 https://t.co/C...
# 13        chunkypots  RT @pkumaaar_: @chunkypots SAYS THE ONE WHO RA...
# 14        chunkypots  @pkumaaar_ wailed like a baby because she foun...
# 15        chunkypots                       @JovanHeer @PRANNAmusic 💁🏽
# 16        chunkypots  @JovanHeer @PRANNAmusic should we ask your gir...
# 17         __Ganjaaa                                 15 cavities 😳woah
# 18        chunkypots  Chai latte at #MulberryCafe https://t.co/nF5OH...
# 19        chunkypots         @thetenspot made it soooo much brighter!!!
# 20        chunkypots  Always the BEST service and amazing manicure a...
# 21        chunkypots  @PRANNAmusic @JovanHeer saving Punjabi girls o...
# 22        chunkypots                            https://t.co/h38Z6iKCZq
# 23        chunkypots  RT @KardashianReact: the worst part about taki...
# 24        chunkypots         my nerves are in high gear 😩 #justbreathe
# 25        chunkypots  @TaranvirSandhu no varun dhawan, your Bollywoo...
# 26        chunkypots  3 more hours of the longest shift of my life left
# 27        chunkypots                                      @rohinghai 😶
# 28        chunkypots                        @rohinghai friendship over.
# 29        chunkypots  If I see anyone tweet a spoiler for #StarWarsT...
# ...              ...                                                ...
# 49970  Itss_angel_cx  RT @qoingnowhere: @juanpalaciosx just like you...
# 49971  Itss_angel_cx  RT @juanpalaciosx: earth quakes keep getting b...
# 49972  Itss_angel_cx  RT @leilonyfdoe: was i the only one that felt ...
# 49973  Itss_angel_cx              RT @mariaochoax: "But does he care":/
# 49974  Itss_angel_cx                     RT @Paulina_rivera_: tear tear
# 49975  Itss_angel_cx  RT @leilonyfdoe: babe is so fucking cute ugh i...
# 49976  Itss_angel_cx           RT @fuckinfrankkie: @Itss_angel_cx nahhh
# 49977  Itss_angel_cx          Someone take me and leilony swimming 🏊😛
# 49970  RT @qoingnowhere: @juanpalaciosx just like you...
# 49971  RT @juanpalaciosx: earth quakes keep getting b...
# 49972  RT @leilonyfdoe: was i the only one that felt ...
# 49973              RT @mariaochoax: "But does he care":/
# 49974                     RT @Paulina_rivera_: tear tear
# 49975  RT @leilonyfdoe: babe is so fucking cute ugh i...
# 49976           RT @fuckinfrankkie: @Itss_angel_cx nahhh
# 49977          Someone take me and leilony swimming 🏊😛
# 49978                                  leilonyfdoe lmao
# 49979  RT @leilonyfdoe: #4 on the test was easy for m...
# 49980  RT @leilonyfdoe: in like 1 or 2 months, babe i...
# 49981  RT @leilonyfdoe: "my toe hurts, wanna rub it" ...
# 49982  RT @irreIevent: everything about u is addictin...
# 49983       RT @Paulina_rivera_: I wish you were here 😔
# 49984  RT @AriannaChairez: Addicted to you&amp;only u...
# 49985  RT @leilonyfdoe: you're too ugly to be a fuckb...
# 49986  Leilony is texting some boy that he tells ever...
# 49987    RT @leilonyfdoe: i want it to be friday already
# 49988                                 RT SexualGif Yes
# 49989  RT @trapabIe: i want your attention but i don'...
# 49990      RT @_trapical: my first thought is always you
# 49991                  RT @fuckinfrankkie: Early outs 😍
# 49992  RT @Fames: The word "love" doesn't mean anythi...
# 49993                      @leilonyfdoe nah bitchhh 😂😂
# 49994                Stay behind bitch 😂😂 @leilonyfdoe
# 49995    RT @fuckinfrankkie: you just dont understand 😉
# 49996           RT @fuckinfrankkie: My stomach hurtss 😭
# 49997  RT @fuckinfrankkie: dont even kick it with tha...
# 49998             RT @MickeyLacoste: I need you the most
# 49999        RT @fuckinfrankkie: @Itss_angel_cx pc | mee
#
# [50000 rows x 3 columns]

# %% [markdown]
# ### Analyze sentiment for each tweet

# %% [markdown]
# #### nltk.sentiment.vader is used because it takes into consideration special case idioms, capitalization, punctuation, and deals specifically with social media texts
#
# VADER (Valence Aware Dictionary and sEntiment Reasoner)
#
# source code: http://www.nltk.org/_modules/nltk/sentiment/vader.html
#
# Github: https://github.com/cjhutto/vaderSentiment
#
# VADER: A Parsimonious Rule-based Model for Sentiment Analysis of Social Media Text
# (by C.J. Hutto and Eric Gilbert)
# Eighth International Conference on Weblogs and Social Media (ICWSM-14). Ann Arbor, MI, June 2014.  http://comp.social.gatech.edu/papers/icwsm14.vader.hutto.pdf

# %%
from nltk.sentiment.sentiment_analyzer import SentimentAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /Users/Kimyen/anaconda/lib/python2.7/site-packages/nltk-3.1-py2.7.egg/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
sid = SentimentIntensityAnalyzer()
user_df['sentiment'] = user_df['text'].apply(lambda x: sid.polarity_scores(x))

# %%
user_df['sentiment']
# Out:
# 0        {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 1        {u'neg': 0.0, u'neu': 0.167, u'pos': 0.833, u'...
# 2        {u'neg': 0.0, u'neu': 0.393, u'pos': 0.607, u'...
# 3        {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 4        {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 5        {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 6        {u'neg': 0.0, u'neu': 0.578, u'pos': 0.422, u'...
# 7        {u'neg': 0.0, u'neu': 0.755, u'pos': 0.245, u'...
# 8        {u'neg': 0.0, u'neu': 0.92, u'pos': 0.08, u'co...
# 9        {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 10       {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 11       {u'neg': 0.0, u'neu': 0.602, u'pos': 0.398, u'...
# 12       {u'neg': 0.0, u'neu': 0.74, u'pos': 0.26, u'co...
# 13       {u'neg': 0.0, u'neu': 0.93, u'pos': 0.07, u'co...
# 14       {u'neg': 0.0, u'neu': 0.828, u'pos': 0.172, u'...
# 15       {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 16       {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 17       {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 18       {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 19       {u'neg': 0.0, u'neu': 0.59, u'pos': 0.41, u'co...
# 20       {u'neg': 0.0, u'neu': 0.458, u'pos': 0.542, u'...
# 21       {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 22       {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 23       {u'neg': 0.249, u'neu': 0.601, u'pos': 0.15, u...
# 24       {u'neg': 0.167, u'neu': 0.833, u'pos': 0.0, u'...
# 25       {u'neg': 0.103, u'neu': 0.769, u'pos': 0.128, ...
# 26       {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 27       {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 28       {u'neg': 0.0, u'neu': 0.408, u'pos': 0.592, u'...
# 29       {u'neg': 0.132, u'neu': 0.868, u'pos': 0.0, u'...
#                                ...
# 49970    {u'neg': 0.306, u'neu': 0.463, u'pos': 0.231, ...
# 49971    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49972    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49973    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49974    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49975    {u'neg': 0.409, u'neu': 0.392, u'pos': 0.2, u'...
# 49976    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49977    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49978    {u'neg': 0.0, u'neu': 0.339, u'pos': 0.661, u'...
# 49979    {u'neg': 0.0, u'neu': 0.818, u'pos': 0.182, u'...
# 49980    {u'neg': 0.115, u'neu': 0.782, u'pos': 0.103, ...
# 49981    {u'neg': 0.237, u'neu': 0.763, u'pos': 0.0, u'...
# 49982    {u'neg': 0.333, u'neu': 0.667, u'pos': 0.0, u'...
# 49983    {u'neg': 0.0, u'neu': 0.69, u'pos': 0.31, u'co...
# 49984    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49985    {u'neg': 0.372, u'neu': 0.473, u'pos': 0.155, ...
# 49986    {u'neg': 0.178, u'neu': 0.719, u'pos': 0.104, ...
# 49987    {u'neg': 0.0, u'neu': 0.843, u'pos': 0.157, u'...
# 49988    {u'neg': 0.0, u'neu': 0.597, u'pos': 0.403, u'...
# 49989    {u'neg': 0.251, u'neu': 0.565, u'pos': 0.184, ...
# 49990    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49991    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49992    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49993    {u'neg': 0.318, u'neu': 0.682, u'pos': 0.0, u'...
# 49994    {u'neg': 0.487, u'neu': 0.513, u'pos': 0.0, u'...
# 49995    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49996    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49997    {u'neg': 0.13, u'neu': 0.758, u'pos': 0.112, u...
# 49998    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# 49999    {u'neg': 0.0, u'neu': 1.0, u'pos': 0.0, u'comp...
# Name: sentiment, dtype: object

# %% [markdown]
# #### Keeping only tweets classified as positive

# %%
pos_user_tweets = user_df[user_df['sentiment'].apply(lambda x: x['pos']) > .49]

# %%
pos_user_tweets
# Out:
#            user_name                                               text  \
# 1         chunkypots                             @thetenspot awesome!!!
# 2         chunkypots              @stajans_girl @pkumaaar_ LMAO YESSSSS
# 20        chunkypots  Always the BEST service and amazing manicure a...
# 28        chunkypots                        @rohinghai friendship over.
# 41        chunkypots             @JovanHeer lol!! Haha okay that's fair
# 50        chunkypots                             @rohinghai LMAO oh god
# 51        chunkypots  @rohinghai LMAO how did you just have that on ...
# 53        chunkypots               @rohinghai you'll need fair n lovely
# 73        chunkypots  Drinks n burgers after work with my best frien...
# 49474  {u'neg': 0.0, u'neu': 0.493, u'pos': 0.507, u'...
# 49514  {u'neg': 0.0, u'neu': 0.455, u'pos': 0.545, u'...
# 49525  {u'neg': 0.0, u'neu': 0.488, u'pos': 0.512, u'...
# 49616  {u'neg': 0.0, u'neu': 0.47, u'pos': 0.53, u'co...
# 49620  {u'neg': 0.0, u'neu': 0.417, u'pos': 0.583, u'...
# 49627  {u'neg': 0.0, u'neu': 0.385, u'pos': 0.615, u'...
# 49629  {u'neg': 0.0, u'neu': 0.476, u'pos': 0.524, u'...
# 49639  {u'neg': 0.0, u'neu': 0.4, u'pos': 0.6, u'comp...
# 49685  {u'neg': 0.0, u'neu': 0.396, u'pos': 0.604, u'...
# 49710  {u'neg': 0.0, u'neu': 0.339, u'pos': 0.661, u'...
# 49787  {u'neg': 0.0, u'neu': 0.441, u'pos': 0.559, u'...
# 49829  {u'neg': 0.0, u'neu': 0.339, u'pos': 0.661, u'...
# 49835  {u'neg': 0.0, u'neu': 0.143, u'pos': 0.857, u'...
# 49836  {u'neg': 0.0, u'neu': 0.435, u'pos': 0.565, u'...
# 49838  {u'neg': 0.0, u'neu': 0.339, u'pos': 0.661, u'...
# 49842  {u'neg': 0.0, u'neu': 0.5, u'pos': 0.5, u'comp...
# 49859  {u'neg': 0.0, u'neu': 0.484, u'pos': 0.516, u'...
# 49908  {u'neg': 0.0, u'neu': 0.189, u'pos': 0.811, u'...
# 49946  {u'neg': 0.0, u'neu': 0.46, u'pos': 0.54, u'co...
# 49952  {u'neg': 0.0, u'neu': 0.478, u'pos': 0.522, u'...
# 49978  {u'neg': 0.0, u'neu': 0.339, u'pos': 0.661, u'...
#
# [2116 rows x 4 columns]

# %%
pos_user_tweets['user_name'].value_counts()
# Out:
# _justolentino     324
# nakiyarussell     241
# emiiistyles       218
# quiwop            171
# chunkypots        160
# trippnationn      141
# lovecoutureee_    132
# Itss_angel_cx     121
# USUAggie1990      114
# ChristinaAAAHD    102
# yungjosey          99
# matt_brownlee8     78
# YZAKALLO           77
# chuck_haze         72
# __Ganjaaa          56
# JULIANAMEGGERS      6
# swnseanews          2
# RadtkeKristin       2
# Name: user_name, dtype: int64

# %% [markdown]
# #### Keeping only tweets classified as non negative

# %%
nneg_user_tweets = user_df[user_df['sentiment'].apply(lambda x: x['neg']) < .49]

# %%
nneg_user_tweets['user_name'].value_counts()
# Out:
# swnseanews        3224
# emiiistyles       3203
# ChristinaAAAHD    3189
# USUAggie1990      3187
# chunkypots        3153
# chuck_haze        3151
# nakiyarussell     3127
# __Ganjaaa         3117
# lovecoutureee_    3115
# _justolentino     3100
# quiwop            3081
# matt_brownlee8    3063
# YZAKALLO          2984
# trippnationn      2907
# Itss_angel_cx     2697
# yungjosey         2242
# JULIANAMEGGERS     196
# RadtkeKristin      100
# royray0              1
# Name: user_name, dtype: int64

# %% [markdown]
# ### Time to stem each tweet using snowball

# %%
pos_user_tweets['stemmed_text'] = pos_user_tweets['simple_text'].apply(lambda sent: ' '.join([snowball.stem(word) for \
                                    word in sent.translate(translation_table).split()]))
nneg_user_tweets['stemmed_text'] = nneg_user_tweets['simple_text'].apply(lambda sent: ' '.join([snowball.stem(word) \
                                   for word in sent.translate(translation_table).split()]))
# Out:
# /Users/Kimyen/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/Kimyen/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Create a list of users

# %%
user_list = nneg_user_tweets['user_name'].value_counts().index
user_list
# Out:
# Index([u'swnseanews', u'emiiistyles', u'ChristinaAAAHD', u'USUAggie1990',
#        u'chunkypots', u'chuck_haze', u'nakiyarussell', u'__Ganjaaa',
#        u'lovecoutureee_', u'_justolentino', u'quiwop', u'matt_brownlee8',
#        u'YZAKALLO', u'trippnationn', u'Itss_angel_cx', u'yungjosey',
#        u'JULIANAMEGGERS', u'RadtkeKristin', u'royray0'],
#       dtype='object')

# %%
# user_vects = defaultdict(list)
# for user in user_list:
#     documents = pos_user_tweets[pos_user_tweets['user_name'] == user].stemmed_text
#     vect_name = 'tfidf_'+user
#     #print documents.values[0]
#     user_vects[vect_name] = tfidf.fit_transform(documents)

# %%
user_docs = []
for user in user_list:
    a = ' '.join([text for text in nneg_user_tweets[nneg_user_tweets['user_name']==user].stemmed_text.values])
    user_docs.append(a)

# %% [markdown]
# ### Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
user_docs_pos = []
for user in user_list:
    a = ' '.join([text for text in pos_user_tweets[pos_user_tweets['user_name']== user].text.values])
    user_docs_pos.append(a)

# %%
user_docs_nneg = []
for user in user_list:
    a = ' '.join([text for text in nneg_user_tweets[nneg_user_tweets['user_name']== user].text.values])
    user_docs_nneg.append(a)

# %%
mini_retailers_df[mini_retailers_df['company'] == 'BNBuzz']
# Out:
#        company                                               text  \
# 214464  BNBuzz  Getting pumped for our #BNGiftRec chat with @J...
# 214465  BNBuzz  Shopping for a teen? We bet these page-and-scr...
# 214466  BNBuzz  Santa is NOT an easy character to catch! Bring...
# 214467  BNBuzz  RT @BNTeens: Jane Austen's EMMA is 200 this mo...
# 214468  BNBuzz  RT @tyleroakley: thanks Barnes &amp; Noble for...
# 214469  BNBuzz  #StarWars fans! We have gift ideas for Jedi of...
# 214470  BNBuzz  RT @Italian_Movies: Don't forget Barnes and No...
# 214471  BNBuzz  RT @BNTeens: 15 of our most anticipated YA deb...
# 214472  BNBuzz  RT @bradtaylorbooks: If you're unable to make ...
# 214473  BNBuzz  RT @cabinporn: Looking for a last minute copy ...
# 214474  BNBuzz  RT @raylewis: Last minute shoppers, @BNBuzz ha...
# 214475  BNBuzz  RT @BNKids: 10 charming Christmas Eve reads we...
# 214476  BNBuzz  We're talking holidays and gifting with @Jerry...
# 214477  BNBuzz  Spotted on The @TODAYshow’s Ultimate Gift Guid...
# 214478  BNBuzz  RT @ToneItUp: Loved chatting with @BNBuzz! Hap...
# 214479  BNBuzz  RT @BNKids: Treating your child to an outing? ...
# 214480  BNBuzz  It's been SO fun chatting, @ToneItUp! Thanks f...
# 214481  BNBuzz  RT @ToneItUp: @BNBuzz I want Lana Del Rey on v...
# 214482  BNBuzz  RT @JoRiker: @BNBuzz @Toneitup im a teacher an...
# 214483  BNBuzz  RT @ToneItUp: @BNBuzz Anything by Dr. Seuss! #...
# 214484  BNBuzz  What do YOU want for Christmas? @ToneItUp #BNG...
# 214485  BNBuzz  What book from childhood should we all reread ...
# 214486  BNBuzz  RT @ToneItUp: @BNBuzz National Lampoons Christ...
# 214487  BNBuzz  What's your favorite Christmas song? @ToneItUp...
# 214488  BNBuzz  What's your favorite Christmas movie? @ToneItU...
# 214489  BNBuzz  RT @ToneItUp: @BNBuzz An adult coloring book! ...
# 214490  BNBuzz  Which book would you buy for a teacher? @ToneI...
# 214491  BNBuzz  RT @ToneItUp: @BNBuzz Karena here! I just boug...
# 214492  BNBuzz  What's the last book you bought for yourself? ...
# 214493  BNBuzz  RT @ToneItUp: @BNBuzz Karena here ~ love givin...
# ...        ...                                                ...
# 217644  BNBuzz  "'I hear it when we're walkin' along, but when...
# 217645  BNBuzz  "'Be careful of haints,' the voice said. 'Bett...
# 217646  BNBuzz  "After that it didn't matter whether they went...
# 217647  BNBuzz  "Jem squeezed me into my costume, stood at the...
# 217648  BNBuzz  "When Halloween came, I assumed that the whole...
# 217649  BNBuzz  "Mrs. Merriweather composed a pageant entitled...
# 217650  BNBuzz  "Mrs. Taylor came home from church to find her...
# 217651  BNBuzz  Getting to hear the first chapter of GO SET A ...
# 217652  BNBuzz  "Jem, how can you hate Hitler so bad an' then ...
# 217653  BNBuzz  "Living in this world we HAVE to talk about it...
# 217654  BNBuzz  A very happy #MockingbirdMonday to all! #GoSet...
# 217655  BNBuzz  "'But it's okay to hate Hitler?' 'It is not,' ...
# 217656  BNBuzz  RT @KevinMHaas: Judge Rosemary Collins says At...
# 217657  BNBuzz  RT @JoseforTexas: Stopping by @BNBuzz El Paso ...
# 217658  BNBuzz  "Listen to the verbs in this thing." @WallyLam...
# 217659  BNBuzz  "People were just peculiar. I withdrew from th...
# 217660  BNBuzz  "I love and admire this new book in a way that...
# 217661  BNBuzz  "It's a much gutsier book than TO KILL A MOCKI...
# 217662  BNBuzz  An amazing TO KILL A MOCKINGBIRD conversation ...
# 217663  BNBuzz  "'You're mighty dressed up Miss Jean Louise' s...
# 217664  BNBuzz  "'There's just one kind of folks. Folks." "If ...
# 217665  BNBuzz  "You know she's not used to girls like you. Sh...
# 217666  BNBuzz  "Why ladies hooked woolen rugs on boiling nigh...
# 217667  BNBuzz  "If you had been on that jury, son, and eleven...
# 217668  BNBuzz  "We don't have anything to fear from Bob Ewell...
# 217669  BNBuzz  "There ain't 1 thing in this world I can do ab...
# 217670  BNBuzz  "And I thought to myself, well, we're making a...
# 217671  BNBuzz  RT @LauraM_Martinez: Enjoying guest reading in...
# 217672  BNBuzz  "We're so rarely called on to be Christians, b...
# 217673  BNBuzz  RT @LizaNahas: @BNBuzz #MockingbirdMonday #TKA...
#
#                                               simple_text  \
# 214464  Getting pumped for our BNGiftRec chat with it ...
# 214465  Shopping for a teen We bet these pageandscreen...
# 214466  Santa is NOT an easy character to catch Bring ...
# 214467    Jane Austens EMMA is 200 this month Celebrat...
# 214468    thanks Barnes amp Noble for listing BINGE as...
# 214469  StarWars fans We have gift ideas for Jedi of a...
# 214470    Dont forget Barnes and Noble for great Itali...
# 214471     15 of our most anticipated YA debuts of 2016
# 214472    If youre unable to make it to one of my stop...
# 214473    Looking for a last minute copy of the  book ...
# 214474    Last minute shoppers  has exclusive signed e...
# 214475    10 charming Christmas Eve reads we love this...
# 214476  Were talking holidays and gifting with  tomorr...
# 214477  Spotted on The s Ultimate Gift Guide roundup M...
# 214478    Loved chatting with  Happy Holiday shopping ...
# 214479    Treating your child to an outing Pair it wit...
# 214480  Its been SO fun chatting  Thanks for the aweso...
# 214481            I want Lana Del Rey on vinyl BNGiftRec
# 214482       im a teacher and we love all books BNGiftRec
# 214483                     Anything by Dr Seuss BNGiftRec
# 214484          What do YOU want for Christmas  BNGiftRec
# 214485  What book from childhood should we all reread ...
# 214486     National Lampoons Christmas Vacation BNGift...
# 214487      Whats your favorite Christmas song  BNGiftRec
# 214488     Whats your favorite Christmas movie  BNGiftRec
# 214489     An adult coloring book Great to destress  B...
# 214490  Which book would you buy for a teacher  BNGiftRec
# 214491     Karena here I just bought My Life On the Ro...
# 214492  Whats the last book you bought for yourself  B...
# 214493     Karena here  love giving people inspiration...
# ...                                                   ...
# 217644  "'I hear it when we're walkin' along, but when...
# 217645  "'Be careful of haints,' the voice said. 'Bett...
# 217646  "After that it didn't matter whether they went...
# 217647  "Jem squeezed me into my costume, stood at the...
# 217648  "When Halloween came, I assumed that the whole...
# 217649  "Mrs. Merriweather composed a pageant entitled...
# 217650  "Mrs. Taylor came home from church to find her...
# 217651  Getting to hear the first chapter of GO SET A ...
# 217652  "Jem, how can you hate Hitler so bad an' then ...
# 217653  Living in this world we HAVE to talk about it ...
# 217654  A very happy MockingbirdMonday to all GoSetAWa...
# 217655  "'But it's okay to hate Hitler?' 'It is not,' ...
# 217656    Judge Rosemary Collins says Atticus Finch wa...
# 217657    Stopping by  El Paso to read chapt 16 ToKill...
# 217658  Listen to the verbs in this thing  reading TO ...
# 217659  "People were just peculiar. I withdrew from th...
# 217660  I love and admire this new book in a way that ...
# 217661  Its a much gutsier book than TO KILL A MOCKING...
# 217662  An amazing TO KILL A MOCKINGBIRD conversation ...
# 217663  "'You're mighty dressed up Miss Jean Louise' s...
# 217664  "'There's just one kind of folks. Folks." "If ...
# 217665  "You know she's not used to girls like you. Sh...
# 217666  "Why ladies hooked woolen rugs on boiling nigh...
# 217667  "If you had been on that jury, son, and eleven...
# 217668  "We don't have anything to fear from Bob Ewell...
# 217669  "There ain't 1 thing in this world I can do ab...
# 217670  "And I thought to myself, well, we're making a...
# 217671    Enjoying guest reading in braille of To Kill...
# 217672  "We're so rarely called on to be Christians, b...
# 217673     MockingbirdMonday TKAM readathon Carmel Wer...
#
#                                              stemmed_text
# 214464  get pump for our bngiftrec chat with it start ...
# 214465  shop for a teen we bet these pageandscreen boo...
# 214466  santa is not an easi charact to catch bring th...
# 214467  jane austen emma is 200 this month celebr with...
# 214468  thank barn amp nobl for list bing as one of no...
# 214469  starwar fan we have gift idea for jedi of all ...
# 214470  dont forget barn and nobl for great italian dv...
# 214471            15 of our most anticip ya debut of 2016
# 214472  if your unabl to make it to one of my stop on ...
# 214473  look for a last minut copi of the book get fre...
# 214474  last minut shopper has exclus sign edit of my ...
# 214475       10 charm christma eve read we love this year
# 214476  were talk holiday and gift with tomorrow at 1p...
# 214477  spot on the s ultim gift guid roundup milli ma...
# 214478  love chat with happi holiday shop everyon bngi...
# 214479  treat your child to an outing pair it with a b...
# 214480  it been so fun chat thank for the awesom advic...
# 214481             i want lana del rey on vinyl bngiftrec
# 214482        im a teacher and we love all book bngiftrec
# 214483                        anyth by dr seuss bngiftrec
# 214484            what do you want for christma bngiftrec
# 214485  what book from childhood should we all reread ...
# 214486            nation lampoon christma vacat bngiftrec
# 214487          what your favorit christma song bngiftrec
# 214488          what your favorit christma movi bngiftrec
# 214489    an adult color book great to destress bngiftrec
# 214490   which book would you buy for a teacher bngiftrec
# 214491  karena here i just bought my life on the road ...
# 214492  what the last book you bought for yourself bng...
# 214493  karena here love give peopl inspir book like t...
# ...                                                   ...
# 217644  'i hear it when we'r walkin along but when we ...
# 217645  be care of haint the voic said better still te...
# 217646  after that it didn't matter whether they went ...
# 217647  jem squeez me into my costum stood at the live...
# 217648  when halloween came i assum that the whole fam...
# 217649  mrs merriweath compos a pageant entitl maycomb...
# 217650  mrs taylor came home from church to find her h...
# 217651  get to hear the first chapter of go set a watc...
# 217652  jem how can you hate hitler so bad an then tur...
# 217653  live in this world we have to talk about it on...
# 217654  a veri happi mockingbirdmonday to all gosetawa...
# 217655  but it okay to hate hitler it is not he said i...
# 217656  judg rosemari collin say atticus finch was an ...
# 217657  stop by el paso to read chapt 16 tokillamockin...
# 217658  listen to the verb in this thing read to kill ...
# 217659  peopl were just peculiar i withdrew from them ...
# 217660  i love and admir this new book in a way that s...
# 217661  it a much gutsier book than to kill a mockingb...
# 217662  an amaz to kill a mockingbird convers w amp is...
# 217663  you'r mighti dress up miss jean louis she said...
# 217664  there just one kind of folk folk if there just...
# 217665  you know she not use to girl like you she tri ...
# 217666  whi ladi hook woolen rug on boil night never b...
# 217667  if you had been on that juri son and eleven ot...
# 217668  we don't have anyth to fear from bob ewel he g...
# 217669  there ain't 1 thing in this world i can do abo...
# 217670  and i thought to myself well we'r make a step—...
# 217671  enjoy guest read in braill of to kill a mockin...
# 217672  we'r so rare call on to be christian but when ...
# 217673  mockingbirdmonday tkam readathon carmel were h...
#
# [3208 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
X = mini_retailers_df['stemmed_text']
y = mini_retailers_df['company']
count_vectorizer = CountVectorizer(stop_words='english')
tf = count_vectorizer.fit_transform(X)
clf = MultinomialNB()
clf.fit(tf, y)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# test for a single tweet, should result in aeriagames
user1 = count_vectorizer.transform(["congratul for the awesom guardian cosplay"])

pred1 = clf.predict(user1)
pred1[0]
# Out:
# 'aeriagames'

# %%
for user in user_docs_pos:
    X1 = count_vectorizer.transform([user])
    pred = clf.predict(X1)
    print pred[0]
# Out:
# amazon
# BabiesRUs
# BNBuzz
# SportsAuthority
# zappos
# BNBuzz
# BabiesRUs
# BNBuzz
# BNBuzz
# BedBathBeyond
# jcpenney
# ToysRUs
# BNBuzz
# ToysRUs
# ToysRUs
# Staples
# ToysRUs
# IHOP
# BedBathBeyond

# %% [markdown]
# ### Use Cosine Similarity to compare documents of user tweets to company tweets
#
# This kernel is a popular choice for computing the similarity of documents represented as tf-idf vectors. cosine_similarity accepts scipy.sparse matrices. (Note that the tf-idf functionality in sklearn.feature_extraction.text can produce normalized vectors, in which case cosine_similarity is equivalent to linear_kernel, only slower.)

# %%
from sklearn.metrics.pairwise import linear_kernel 
import numpy as np

# %%
# With positive tweets only

from copy import copy

vect = TfidfVectorizer(stop_words='english')
i = 1
for user_tweets in user_docs_pos:
    all_docs = copy(com_docs)
    all_docs.append(user_tweets)

    X = vect.fit_transform(all_docs)
    M = linear_kernel(X, X)
    sortedM = np.argsort(M[-1])[::-1][1:3]
    a, b = company_list[sortedM]
    numA, numB = M[-1][sortedM]
    print "{}) Top matches: {} ({}%) and {} ({}%)".format(i, a, round(numA * 100, 2), b, round(numB * 100, 2))
    i += 1
# Out:
# 1) Top matches: Aeropostale (2.0%) and amazon (1.96%)
# 2) Top matches: lushcosmetics (11.41%) and BananaRepublic (9.38%)
# 3) Top matches: lushcosmetics (16.82%) and lululemon (13.29%)
# 4) Top matches: SportsAuthority (11.27%) and lululemon (9.92%)
# 5) Top matches: lululemon (5.5%) and lushcosmetics (5.23%)
# 6) Top matches: lululemon (6.09%) and SportsAuthority (5.45%)
# 7) Top matches: lushcosmetics (14.33%) and BananaRepublic (11.75%)
# 8) Top matches: lushcosmetics (6.38%) and BananaRepublic (5.31%)
# 9) Top matches: lushcosmetics (13.68%) and BananaRepublic (11.0%)
# 10) Top matches: BedBathBeyond (8.58%) and BananaRepublic (4.63%)
# 11) Top matches: lushcosmetics (11.82%) and BananaRepublic (9.9%)
# 12) Top matches: lushcosmetics (8.7%) and BananaRepublic (8.23%)
# 13) Top matches: lululemon (7.76%) and lushcosmetics (6.87%)
# 14) Top matches: lululemon (6.5%) and lushcosmetics (5.84%)
# 15) Top matches: lushcosmetics (5.12%) and BananaRepublic (4.79%)
# 16) Top matches: BedBathBeyond (3.55%) and lululemon (2.59%)
# 17) Top matches: lushcosmetics (2.95%) and BananaRepublic (2.55%)
# 18) Top matches: IHOP (4.53%) and lushcosmetics (4.03%)
# 19) Top matches: SUBWAY (0.0%) and Forever21 (0.0%)

# %%
# With nonnegative tweets

from copy import copy

vect = TfidfVectorizer(stop_words='english')
i = 1
for user_tweets in user_docs_nneg:
    all_docs = copy(com_docs)
    all_docs.append(user_tweets)

    X = vect.fit_transform(all_docs)
    M = linear_kernel(X, X)
    sortedM = np.argsort(M[-1])[::-1][1:3]
    a, b = company_list[sortedM]
    numA, numB = M[-1][sortedM]
    print "{}) Top matches: {} ({}%) and {} ({}%)".format(i, a, round(numA * 100, 2), b, round(numB*100, 2))
    i += 1
# Out:
# 1) Top matches: Disney (0.71%) and amazon (0.66%)
# 2) Top matches: hotelsdotcom (3.76%) and SportsAuthority (3.05%)
# 3) Top matches: lululemon (6.29%) and SportsAuthority (4.72%)
# 4) Top matches: SportsAuthority (7.41%) and AppStore (6.43%)
# 5) Top matches: lululemon (7.44%) and SportsAuthority (6.03%)
# 6) Top matches: lululemon (5.41%) and hotelsdotcom (4.96%)
# 7) Top matches: lululemon (5.99%) and SportsAuthority (5.28%)
# 8) Top matches: hotelsdotcom (3.46%) and lululemon (2.39%)
# 9) Top matches: lululemon (4.24%) and hotelsdotcom (4.2%)
# 10) Top matches: BedBathBeyond (4.67%) and BananaRepublic (2.66%)
# 11) Top matches: lululemon (7.45%) and SportsAuthority (6.87%)
# 12) Top matches: hotelsdotcom (3.93%) and lululemon (3.73%)
# 13) Top matches: lululemon (7.13%) and SportsAuthority (5.94%)
# 14) Top matches: lululemon (4.12%) and hotelsdotcom (4.09%)
# 15) Top matches: hotelsdotcom (3.5%) and lululemon (3.29%)
# 16) Top matches: lululemon (4.42%) and hotelsdotcom (4.03%)
# 17) Top matches: lululemon (6.44%) and SportsAuthority (5.79%)
# 18) Top matches: hotelsdotcom (2.55%) and SportsAuthority (2.22%)
# 19) Top matches: amazon (0.51%) and AppStore (0.45%)

# %%
# cosine similartity between stores & 1 user
test_doc = copy(com_docs)
test_doc.append(user_docs[0])

vect = TfidfVectorizer(stop_words='english')
X = vect.fit_transform(test_doc)
M = linear_kernel(X, X)
sortedM = np.argsort(M[-1])[::-1][1:3]
a, b = company_list[sortedM]
print a, b
print M[-1]

# %%
# top features

indices = np.argsort(vect.idf_)[::-1]
features= vect.get_feature_names()
top_n = 20
top_features = [features[i] for i in indices[:top_n]]
print top_features

# %%
company_list[sortedM2]

# %%
sortedM2 = np.argsort(M[-1])[::-1][1:3]

# %% [markdown]
# ### Trying out OneVsRestClassifier

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC # using LinearSVC since it works well with a large number of features

# %%
X = mini_retailers_df['stemmed_text']
y = mini_retailers_df['company']
tfid_vectorizer = TfidfVectorizer(stop_words='english')
tf3 = tfid_vectorizer.fit_transform(X)
OvR = OneVsRestClassifier(LinearSVC(random_state=0))
OvR.fit(tf3, y)
# Out:
# OneVsRestClassifier(estimator=LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=0, tol=0.0001,
#      verbose=0),
#           n_jobs=1)

# %%
for user in user_docs_pos:
    X1 = tfid_vectorizer.transform([user])
    pred = OvR.predict(X1)
    print pred
# Out:
# ['Ticketmaster']
# ['UrbanOutfitters']
# ['hotelsdotcom']
# ['SportsAuthority']
# ['zappos']
# ['hotelsdotcom']
# ['hotelsdotcom']
# ['hotelsdotcom']
# ['hotelsdotcom']
# ['BedBathBeyond']
# ['zappos']
# ['hotelsdotcom']
# ['hotelsdotcom']
# ['hotelsdotcom']
# ['UrbanOutfitters']
# ['BedBathBeyond']
# ['UrbanOutfitters']
# ['IHOP']
# ['ChickfilA']

# %%
user = "love music macbook album rap pop billboard"
X1 = tfid_vectorizer.transform([user])
pred = OvR.predict_proba(X1)
print pred
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-140-505339975b22> in <module>()
#       1 user = "love music macbook album rap pop billboard"
#       2 X1 = tfid_vectorizer.transform([user])
# ----> 3 pred = OvR.predict_proba(X1)
#       4 print pred
#
# /Users/Kimyen/anaconda/lib/python2.7/site-packages/sklearn/multiclass.pyc in predict_proba(self, X)
#     356         # Y[i,j] gives the probability that sample i has the label j.
#     357         # In the multi-label case, these are not disjoint.
# --> 358         Y = np.array([e.predict_proba(X)[:, 1] for e in self.estimators_]).T
#     359
#     360         if len(self.estimators_) == 1:
#
# AttributeError: 'LinearSVC' object has no attribute 'predict_proba'

# %% [markdown]
# ### Assess accuracy of the models by splitting up training data (stores)

# %%
from sklearn.cross_validation import train_test_split

# %%
X = mini_retailers_df['stemmed_text']
y = mini_retailers_df['company']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# MultinomialNB

count_vectorizer = CountVectorizer(stop_words='english')
tf_nb = count_vectorizer.fit_transform(X_train)
clf = MultinomialNB()
clf.fit(tf_nb, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
test_cv = count_vectorizer.transform(X_test)

clf.score(test_cv, y_test)
# Out:
# 0.60408222350897511

# %%
# OneVsRest

tfid_vectorizer = TfidfVectorizer(stop_words='english')
tf_OvR = tfid_vectorizer.fit_transform(X_train)
OvR = OneVsRestClassifier(LinearSVC(random_state=0))
OvR.fit(tf_OvR, y_train)
# Out:
# OneVsRestClassifier(estimator=LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=0, tol=0.0001,
#      verbose=0),
#           n_jobs=1)

# %%
test_OvR = tfid_vectorizer.transform(X_test)

OvR.score(test_OvR, y_test)
# Out:
# 0.69554622659718202

# %% [markdown]
# ### Looks like OvR is better than NB, but lets test with KFolds CV

# %%
from sklearn.cross_validation import KFold

# %%
n = len(y) # 207237
kf = KFold(n, n_folds=7, shuffle=True, random_state=7)

# %%
# iloc is used because some indeces are skipped, can see difference with max(index) & len(index)
# can fix with X.index = range(len(X))

for train_index, test_index in kf:
    test = train_index
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    count_vectorizer = CountVectorizer(stop_words='english')
    tf_nb = count_vectorizer.fit_transform(X_train)
    clf = MultinomialNB()
    clf.fit(tf_nb, y_train)
    
    tfid_vectorizer = TfidfVectorizer(stop_words='english')
    tf_OvR = tfid_vectorizer.fit_transform(X_train)
    OvR = OneVsRestClassifier(LinearSVC(random_state=0))
    OvR.fit(tf_OvR, y_train)
    
    test_cv = count_vectorizer.transform(X_test)
    test_OvR = tfid_vectorizer.transform(X_test)
    
    print "MultinomialNB score: {} \nOvR score: {}\n".format(clf.score(test_cv, y_test), OvR.score(test_OvR, y_test))
# Out:
# MultinomialNB score: 0.602648111869
# OvR score: 0.69594001216
#
# MultinomialNB score: 0.609977707222
# OvR score: 0.700094575424
#
# MultinomialNB score: 0.604526262456
# OvR score: 0.698395541294
#
# MultinomialNB score: 0.605100489782
# OvR score: 0.69863198784
#
# MultinomialNB score: 0.604424928222
# OvR score: 0.700287113663
#
# MultinomialNB score: 0.605269380172
# OvR score: 0.692788380341
#
# MultinomialNB score: 0.607093396386
# OvR score: 0.69829420706

# %% [markdown]
# #### Conclusion: OvR is consistently more accurate than MultinomialNB by ~10%

# %%
len(X)
# Out:
# 207237

# %%
X.iloc[[0, 1, 3, 207211]]
# Out:
# 0         latest dragomon hunter updat introduc 300 vers...
# 1         swear allegi to the free trapper or warden fed...
# 3          congratul for your eo costum and prize so awesom
# 217648    when halloween came i assum that the whole fam...
# Name: stemmed_text, dtype: object

# %%
X[[0, 1, 3, 207211]]
# Out:
# 0         latest dragomon hunter updat introduc 300 vers...
# 1         swear allegi to the free trapper or warden fed...
# 3          congratul for your eo costum and prize so awesom
# 207211
# Name: stemmed_text, dtype: object

# %%
max(X.index)
# Out:
# 217673

# %%
len(X)
# Out:
# 207237
